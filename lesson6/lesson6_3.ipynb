# %%
print("hello")
# Out:
# hello

# %%
import asyncio
from crawl4ai import AsyncWebCrawler

async def main():
    async with AsyncWebCrawler() as crawler:
        result = await crawler.arun('https://www.bnext.com.tw/')
        print(result.markdown[:300]) 

if __name__ == "__main__":
    await main()
# Out:
# [INIT].... → Crawl4AI 0.7.7
# [FETCH]... ↓ https://www.bnext.com.tw/                                                                            |
# ✓ | ⏱: 1.01s
# [SCRAPE].. ◆ https://www.bnext.com.tw/                                                                            |
# ✓ | ⏱: 0.08s
# [COMPLETE] ● https://www.bnext.com.tw/                                                                            |
# ✓ | ⏱: 1.09s
# ![](https://cdn.bnextmedia.com.tw/assets/bn/logocky.png)
#   1. [關於我們](https://www.bnextmedia.com.tw/bn/index.html "前往關於我們")
#   2. [廣告合作](https://bnextmedia.s3.hicloud.net.tw/pdf/saleskit.pdf "前往廣告合作")
#   3. [內容授權](https://www.bnext.com.tw/article/57040 "前往內容授權")
#
#
# [ ![web-logo](https://cdn.bnextmedia.c

# %%
import asyncio
from crawl4ai import AsyncWebCrawler, BrowserConfig, CrawlerRunConfig, CacheMode

async def config_main():
    # 1. 配置瀏覽器
    browser_config = BrowserConfig(
        headless = False
    )

    # 2. 配置爬取行為
    run_config = CrawlerRunConfig(
        cache_mode = CacheMode.BYPASS # 繞過快取，每次重新抓取
    )

    # 3. 執行爬蟲
    async with AsyncWebCrawler(config = browser_config) as crawler:
        result = await crawler.arun(
            url = 'https://www.bnext.com.tw/',
            config = run_config
        )
        print(result.markdown[:300]) 


if __name__ == "__main__":
    await config_main()
